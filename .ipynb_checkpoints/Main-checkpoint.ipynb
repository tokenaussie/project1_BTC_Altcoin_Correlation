# %%
import pandas as pd
#Import ethereum function I've created - it reads the CSV and drops unneeded columns
from reader import reader
from pathlib import Path

# %%
eth_df = reader(file1 = "Resources\ETH_USD.csv", ticker1 = "ETH")
eth_df.head()
# Out:
#                 ETH
# Date
# 2018-01-18   991.01
# 2018-01-19   979.57
# 2018-01-20  1178.29
# 2018-01-21  1022.74
# 2018-01-22   999.37

# %%
vet_df = reader(file1 = "Resources\VET_USD.csv", ticker1 = "VET")
vet_df.head()
# Out:
#                 VET
# Date
# 2018-08-06  0.01342
# 2018-08-07  0.01294
# 2018-08-08  0.01087
# 2018-08-09  0.01155
# 2018-08-10  0.00958

# %%
btc_df = reader(file1 = "Resources\Bitcoin.csv", ticker1 = "BTC")
btc_df.head()
# Out:
#                 BTC
# Date
# 2018-01-01  13444.9
# 2018-01-02  14754.1
# 2018-01-03  15156.6
# 2018-01-04  15180.1
# 2018-01-05  16954.8

# %%
ada_df = reader(file1 = "Resources\Cardano.csv", ticker1 = "ADA")
ada_df.head()
# Out:
#                  ADA
# Date
# 2018-01-01  0.702200
# 2018-01-02  0.762000
# 2018-01-03  1.080000
# 2018-01-04  1.104300
# 2018-01-05  0.994903

# %%
daily_returns = pd.concat([eth_df, vet_df, btc_df, ada_df], axis="columns", join="inner")
daily_returns
# Out:
#                 ETH       VET      BTC       ADA
# Date
# 2018-08-06   405.67  0.013420   6943.6  0.129543
# 2018-08-07   378.46  0.012940   6724.9  0.123807
# 2018-08-08   355.35  0.010870   6283.6  0.112771
# 2018-08-09   362.49  0.011550   6538.8  0.121940
# 2018-08-10   331.50  0.009580   6152.3  0.114628
# ...             ...       ...      ...       ...
# 2021-03-26  1698.95  0.089864  55036.1  1.214457
# 2021-03-27  1711.84  0.088533  55862.9  1.176785
# 2021-03-28  1687.27  0.090733  55765.2  1.189546
# 2021-03-29  1816.19  0.091995  57616.2  1.202812
# 2021-03-30  1838.14  0.089857  58771.3  1.226979
#
# [963 rows x 4 columns]

# %%
eth_max = max(daily_returns['ETH'])
vet_max = max(daily_returns['VET'])
btc_max = max(daily_returns['BTC'])
ada_max = max(daily_returns['ADA'])
print(eth_max)
print(vet_max)
print(btc_max)
print(ada_max)
# Out:
# 1955.16
# 0.093639
# 61195.3
# 1.377406

# %%
eth_btc_ratio = btc_max / eth_max
vet_btc_ratio = btc_max / vet_max
ada_btc_ratio = btc_max / ada_max
btc_btc_ratio = btc_max

# %%
eth_normalised_returns = daily_returns['ETH'] * eth_btc_ratio
vet_normalised_returns = daily_returns['VET'] * vet_btc_ratio
ada_normalised_returns = daily_returns['ADA'] * ada_btc_ratio

# %%
normalised_returns = pd.concat([eth_normalised_returns, vet_normalised_returns, daily_returns['BTC'], ada_normalised_returns], axis="columns", join="inner")
normalised_returns = normalised_returns / btc_max
normalised_returns
# Out:
#                  ETH       VET       BTC       ADA
# Date
# 2018-08-06  0.207487  0.143316  0.113466  0.094049
# 2018-08-07  0.193570  0.138190  0.109892  0.089884
# 2018-08-08  0.181750  0.116084  0.102681  0.081872
# 2018-08-09  0.185402  0.123346  0.106851  0.088529
# 2018-08-10  0.169551  0.102308  0.100535  0.083220
# ...              ...       ...       ...       ...
# 2021-03-26  0.868957  0.959686  0.899352  0.881699
# 2021-03-27  0.875550  0.945471  0.912863  0.854349
# 2021-03-28  0.862983  0.968966  0.911266  0.863613
# 2021-03-29  0.928921  0.982443  0.941513  0.873244
# 2021-03-30  0.940148  0.959611  0.960389  0.890790
#
# [963 rows x 4 columns]

# %%
# Plot daily returns of all portfolios
normalised_returns.plot(figsize = (20,10), title = 'Daily returns for all portfolios')
# Out:
# <AxesSubplot:title={'center':'Daily returns for all portfolios'}, xlabel='Date'>

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + normalised_returns).cumprod() - 1
cumulative_returns.head()
# Out:
#                  ETH       VET       BTC       ADA
# Date
# 2018-08-06  0.207487  0.143316  0.113466  0.094049
# 2018-08-07  0.441220  0.301312  0.235828  0.192386
# 2018-08-08  0.703161  0.452373  0.362724  0.290009
# 2018-08-09  1.018930  0.631518  0.508333  0.404212
# 2018-08-10  1.361243  0.798435  0.659974  0.521071

# %%
cumulative_returns.plot(figsize = (20,10), title = 'Cumulative returns for all crypto')
# Out:
# <AxesSubplot:title={'center':'Cumulative returns for all crypto'}, xlabel='Date'>
